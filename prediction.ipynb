# %%
import numpy as np
import pandas as pd
import torch
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn
from sklearn.preprocessing import MinMaxScaler

# %%
from models import lstm7030_12h
# Out:
# Epoch [10/100], Loss: 0.027783
# Epoch [20/100], Loss: 0.003708
# Epoch [30/100], Loss: 0.002760
# Epoch [40/100], Loss: 0.005624
# Epoch [50/100], Loss: 0.003943
# Epoch [60/100], Loss: 0.002681
# Epoch [70/100], Loss: 0.000611
# Epoch [80/100], Loss: 0.002079
# Epoch [90/100], Loss: 0.003083
# Epoch [100/100], Loss: 0.003715
# Test Loss: 0.004659

# %%
from models import lstm7030_24h
# Out:
# Epoch [10/100], Loss: 0.000356
# Epoch [20/100], Loss: 0.002225
# Epoch [30/100], Loss: 0.000464
# Epoch [40/100], Loss: 0.000834
# Epoch [50/100], Loss: 0.002622
# Epoch [60/100], Loss: 0.010411
# Epoch [70/100], Loss: 0.000652
# Epoch [80/100], Loss: 0.004263
# Epoch [90/100], Loss: 0.000093
# Epoch [100/100], Loss: 0.026237
# Test Loss: 0.004725

# %%
from models import lstm8020_12h
# Out:
# Epoch [10/100], Loss: 0.013008
# Epoch [20/100], Loss: 0.003311
# Epoch [30/100], Loss: 0.004088
# Epoch [40/100], Loss: 0.002220
# Epoch [50/100], Loss: 0.005846
# Epoch [60/100], Loss: 0.003680
# Epoch [70/100], Loss: 0.005242
# Epoch [80/100], Loss: 0.002896
# Epoch [90/100], Loss: 0.001865
# Epoch [100/100], Loss: 0.001998
# Test Loss: 0.004731

# %%
from models import lstm8020_24h
# Out:
# Epoch [10/100], Loss: 0.002976
# Epoch [20/100], Loss: 0.003936
# Epoch [30/100], Loss: 0.003041
# Epoch [40/100], Loss: 0.002984
# Epoch [50/100], Loss: 0.004086
# Epoch [60/100], Loss: 0.001816
# Epoch [70/100], Loss: 0.001669
# Epoch [80/100], Loss: 0.001899
# Epoch [90/100], Loss: 0.003638
# Epoch [100/100], Loss: 0.003898
# Test Loss: 0.005089

# %%
from models import bilstm7030_12h
# Out:
# Epoch [10/100], Loss: 0.000862
# Epoch [20/100], Loss: 0.001283
# Epoch [30/100], Loss: 0.000970
# Epoch [40/100], Loss: 0.004781
# Epoch [50/100], Loss: 0.000828
# Epoch [60/100], Loss: 0.001061
# Epoch [70/100], Loss: 0.000441
# Epoch [80/100], Loss: 0.003214
# Epoch [90/100], Loss: 0.001945
# Epoch [100/100], Loss: 0.001248
# Test Loss: 0.004456

# %%
from models import bilstm7030_24h
# Out:
# Epoch [10/100], Loss: 0.001475
# Epoch [20/100], Loss: 0.008626
# Epoch [30/100], Loss: 0.000983
# Epoch [40/100], Loss: 0.000802
# Epoch [50/100], Loss: 0.000028
# Epoch [60/100], Loss: 0.000084
# Epoch [70/100], Loss: 0.000009
# Epoch [80/100], Loss: 0.033922
# Epoch [90/100], Loss: 0.002515
# Epoch [100/100], Loss: 0.000780
# Test Loss: 0.004427

# %%
from models import bilstm8020_12h
# Out:
# Epoch [10/100], Loss: 0.004546
# Epoch [20/100], Loss: 0.002461
# Epoch [30/100], Loss: 0.000925
# Epoch [40/100], Loss: 0.002508
# Epoch [50/100], Loss: 0.002016
# Epoch [60/100], Loss: 0.001944
# Epoch [70/100], Loss: 0.001477
# Epoch [80/100], Loss: 0.005250
# Epoch [90/100], Loss: 0.001950
# Epoch [100/100], Loss: 0.003403
# Test Loss: 0.004733

# %%
from models import bilstm8020_24h
# Out:
# Epoch [10/100], Loss: 0.003958
# Epoch [20/100], Loss: 0.009078
# Epoch [30/100], Loss: 0.004593
# Epoch [40/100], Loss: 0.001018
# Epoch [50/100], Loss: 0.002723
# Epoch [60/100], Loss: 0.009444
# Epoch [70/100], Loss: 0.004572
# Epoch [80/100], Loss: 0.007735
# Epoch [90/100], Loss: 0.000654
# Epoch [100/100], Loss: 0.001447
# Test Loss: 0.004387
